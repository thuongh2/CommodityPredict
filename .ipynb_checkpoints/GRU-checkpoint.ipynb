# %% [markdown]
# ## Dự đoán giá lúa với LSTM và GRU

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler, StandardScaler

import warnings
warnings.filterwarnings('ignore')

from plotly.subplots import make_subplots
import plotly.graph_objects as go
import plotly.io as pi
import plotly.express as px

from scipy import stats
# %matplotlib inline

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential, layers, callbacks
from tensorflow.keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional

# %% [markdown]
# ### EDA

# %%
df = pd.read_csv('./data.csv',  parse_dates=['date'], index_col='date')

# %%
def timeseries (x_axis, y_axis, x_label):
    plt.figure(figsize = (10, 6))
    plt.plot(x_axis, y_axis, color ='black')
    plt.xlabel(x_label, {'fontsize': 12}) 
    plt.ylabel('Price', {'fontsize': 12})

# %%
dataset = df.copy()
timeseries(df.index, dataset['price'], 'Time (day)')

# %%
df.index
# Out:
# DatetimeIndex(['2008-01-15', '2008-02-15', '2008-03-15', '2008-04-15',
#                '2008-05-15', '2008-06-15', '2008-07-15', '2008-08-15',
#                '2008-09-15', '2008-10-15',
#                ...
#                '2022-12-15', '2023-01-15', '2023-02-15', '2023-03-15',
#                '2023-04-15', '2023-05-15', '2023-06-15', '2023-07-15',
#                '2023-08-15', '2023-09-15'],
#               dtype='datetime64[ns]', name='date', length=189, freq=None)

# %%
# Check for missing values
df = df.loc[:,['price']]
df.head()
# Out:
#                price
# date
# 2008-01-15  5331.605
# 2008-02-15  5787.000
# 2008-03-15  6549.875
# 2008-04-15  7222.500
# 2008-05-15  8588.890

# %%
print('Total num of missing values:') 
print(df.price.isna().sum())
df.price.isna()
# Out:
# Total num of missing values:
# 0
# date
# 2008-01-15    False
# 2008-02-15    False
# 2008-03-15    False
# 2008-04-15    False
# 2008-05-15    False
#               ...
# 2023-05-15    False
# 2023-06-15    False
# 2023-07-15    False
# 2023-08-15    False
# 2023-09-15    False
# Name: price, Length: 189, dtype: bool

# %%
df[df.index.duplicated()]
# Out:
# Empty DataFrame
# Columns: [price]
# Index: []

# %%
df.dropna(subset=['price'], inplace=True)

# %%
df = df.groupby('date', as_index=True).mean()
df.head()
# Out:
#                price
# date
# 2008-01-15  5331.605
# 2008-02-15  5787.000
# 2008-03-15  6549.875
# 2008-04-15  7222.500
# 2008-05-15  8588.890

# %%
df.shape
# Out:
# (189, 1)

# %%
plt.figure(figsize=(10, 6))
plt.boxplot(df)
plt.ylabel("Shampoo revenue", fontsize=12)
plt.title("Boxplot of Shampoo revenue in three years", fontsize=18)
plt.show()

# %%
def detect_outliers(series):
  """
    series: 1-D numpy array input
  """
  Q1 = np.quantile(series, 0.25)
  Q3 = np.quantile(series, 0.75)
  IQR = Q3-Q1
  lower_bound = Q1-1.5*IQR
  upper_bound = Q3+1.5*IQR
  lower_compare = series <= lower_bound
  upper_compare = series >= upper_bound
  outlier_idxs = np.where(lower_compare | upper_compare)[0]
  return outlier_idxs

outlier_idxs=detect_outliers(df)
print("Outlier indices: ", outlier_idxs)
print("Outlier values: ", df.iloc[outlier_idxs])
# Out:
# Outlier indices:  [156 157 158]
# Outlier values:                price
# date
# 2021-01-15  11191.0
# 2021-02-15  11100.0
# 2021-03-15  10841.0

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt
import matplotlib as mpl

mpl.rc("figure", figsize=(10, 6))
plot_acf(df["price"], lags = 12)

# %%
import numpy as np
from scipy import signal

x_detrend = signal.detrend(df["price"])
df_detrend = pd.DataFrame({"Sales_Detrend": x_detrend}, index=df.index)

plt.figure(figsize=(10, 6))
plt.plot(df["price"], label="x")
plt.plot(df_detrend, label="x_detrend")
plt.xticks(rotation=45)
plt.xlabel("Time", fontsize=12)
plt.ylabel("Shampoo revenue", fontsize=12)
plt.legend(fontsize=12)
plt.title("Shampoo revenue in three years", fontsize=18)
plt.show()

# %% [markdown]
# ### Tạo dữ liệu huấn luyện

# %%
dataset = df.copy()
dataset = dataset.resample('W').ffill()
# Split train data and test data
train_size = int(len(dataset)*0.8)

# train_data = df.WC.loc[:train_size] -----> it gives a series
# Do not forget use iloc to select a number of rows
train_data = dataset.iloc[:train_size]
test_data = dataset.iloc[train_size:]

# %%
print(train_data.shape)
print(test_data.shape)

train_size
# Out:
# (654, 1)
# (164, 1)
# 654

# %%
# Scale data
# The input to scaler.fit -> array-like, sparse matrix, dataframe of shape (n_samples, n_features)
scaler = MinMaxScaler().fit(train_data)

train_scaled = scaler.transform(train_data)
test_scaled = scaler.transform(test_data)

# %%
print(train_scaled.shape)
print(test_scaled.shape)
# Out:
# (654, 1)
# (164, 1)

# %%
# Create input dataset
# Th input shape should be [samples, time steps, features]
def create_dataset (X, look_back = 12):
    Xs, ys = [], []
    
    for i in range(len(X)-look_back):
        v = X[i:i+look_back]
        Xs.append(v)
        ys.append(X[i+look_back])

    return np.array(Xs), np.array(ys)
# Gia 12 thang
look_back = 48
X_train, y_train = create_dataset(train_scaled, look_back)
X_test, y_test = create_dataset(test_scaled, look_back)

print('X_train.shape: ', X_train.shape)
print('y_train.shape: ', y_train.shape)
print('X_test.shape: ', X_test.shape) 
print('y_test.shape: ', y_test.shape)
# Out:
# X_train.shape:  (606, 48, 1)
# y_train.shape:  (606, 1)
# X_test.shape:  (116, 48, 1)
# y_test.shape:  (116, 1)

# %% [markdown]
# ### Định nghĩa mô hình

# %%
# Create GRU model
def create_gru(units):
    model = Sequential()
    # Input layer 
    model.add(GRU (units = units, return_sequences = True, 
                 input_shape = (X_train.shape[1], X_train.shape[2])))
    model.add(Dropout(0.2)) 
      # Hidden layer
    model.add(GRU (units = units,  return_sequences=True))                
    model.add(Dropout(0.2))
    # Hidden layer
    model.add(GRU(units = units))                        
    model.add(Dropout(0.2))
    model.add(Dense(units = 1)) 
    #Compile model
    model.compile(loss='mean_squared_error', optimizer='adam')
   
    return model
model_gru = create_gru(64)

# %%
def create_lstm(units):
    model = Sequential()
    # Input layer
    model.add(LSTM(units = units, return_sequences=True, 
                            input_shape=(X_train.shape[1], X_train.shape[2])))
    model.add(Dropout(0.2)) 
    # Hidden layer
    model.add(LSTM(units = units, return_sequences=True))
    model.add(Dropout(0.2)) 
    model.add(LSTM(units = units))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    #Compile model
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model
   
model_lstm = create_lstm(64)

# %%
def fit_model(model):
    history = model.fit(X_train, y_train, epochs = 100, batch_size = 32, shuffle = False)
    return history

# %%
history_gru = fit_model(model_gru)
# Out:
# Epoch 1/100
# 19/19 [==============================] - 8s 61ms/step - loss: 0.0380
# Epoch 2/100
# 19/19 [==============================] - 1s 71ms/step - loss: 0.0133
# Epoch 3/100
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0125
# Epoch 4/100
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0107
# Epoch 5/100
# 19/19 [==============================] - 1s 54ms/step - loss: 0.0106
# Epoch 6/100
# 19/19 [==============================] - 1s 56ms/step - loss: 0.0077
# Epoch 7/100
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0075
# Epoch 8/100
# 19/19 [==============================] - 1s 68ms/step - loss: 0.0076
# Epoch 9/100
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0075
# Epoch 10/100
# 19/19 [==============================] - 1s 55ms/step - loss: 0.0066
# Epoch 11/100
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0066
# Epoch 12/100
# 19/19 [==============================] - 1s 55ms/step - loss: 0.0060
# Epoch 13/100
# 19/19 [==============================] - 1s 56ms/step - loss: 0.0067
# Epoch 14/100
# 19/19 [==============================] - 1s 56ms/step - loss: 0.0059
# Epoch 15/100
# 19/19 [==============================] - 1s 56ms/step - loss: 0.0064
# Epoch 16/100
# 19/19 [==============================] - 1s 57ms/step - loss: 0.0060
# Epoch 17/100
# 19/19 [==============================] - 1s 56ms/step - loss: 0.0072
# Epoch 18/100
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0059
# Epoch 19/100
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0078
# Epoch 20/100
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0052
# Epoch 21/100
# 19/19 [==============================] - 1s 64ms/step - loss: 0.0065
# Epoch 22/100
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0052
# Epoch 23/100
# 19/19 [==============================] - 1s 55ms/step - loss: 0.0053
# Epoch 24/100
# 19/19 [==============================] - 1s 54ms/step - loss: 0.0051
# Epoch 25/100
# 19/19 [==============================] - 1s 52ms/step - loss: 0.0049
# Epoch 26/100
# 19/19 [==============================] - 1s 52ms/step - loss: 0.0049
# Epoch 27/100
# 19/19 [==============================] - 1s 51ms/step - loss: 0.0046
# Epoch 28/100
# 19/19 [==============================] - 1s 54ms/step - loss: 0.0048
# Epoch 29/100
# 19/19 [==============================] - 1s 54ms/step - loss: 0.0048
# Epoch 30/100
# 19/19 [==============================] - 1s 53ms/step - loss: 0.0044
# Epoch 31/100
# 19/19 [==============================] - 1s 51ms/step - loss: 0.0050
# Epoch 32/100
# 19/19 [==============================] - 1s 51ms/step - loss: 0.0054
# Epoch 33/100
# 19/19 [==============================] - 1s 57ms/step - loss: 0.0058
# Epoch 34/100
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0065
# Epoch 35/100
# 19/19 [==============================] - 1s 79ms/step - loss: 0.0063
# Epoch 36/100
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0097
# Epoch 37/100
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0041
# Epoch 38/100
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0041
# Epoch 39/100
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0040
# Epoch 40/100
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0043
# Epoch 41/100
# 19/19 [==============================] - 1s 54ms/step - loss: 0.0040
# Epoch 42/100
# 19/19 [==============================] - 1s 55ms/step - loss: 0.0048
# Epoch 43/100
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0038
# Epoch 44/100
# 19/19 [==============================] - 1s 64ms/step - loss: 0.0041
# Epoch 45/100
# 19/19 [==============================] - 1s 56ms/step - loss: 0.0038
# Epoch 46/100
# 19/19 [==============================] - 1s 57ms/step - loss: 0.0037
# Epoch 47/100
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0038
# Epoch 48/100
# 19/19 [==============================] - 1s 52ms/step - loss: 0.0039
# Epoch 49/100
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0041
# Epoch 50/100
# 19/19 [==============================] - 1s 57ms/step - loss: 0.0038
# Epoch 51/100
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0040
# Epoch 52/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0042
# Epoch 53/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0044
# Epoch 54/100
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0053
# Epoch 55/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0046
# Epoch 56/100
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0061
# Epoch 57/100
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0043
# Epoch 58/100
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0039
# Epoch 59/100
# 19/19 [==============================] - 1s 51ms/step - loss: 0.0037
# Epoch 60/100
# 19/19 [==============================] - 1s 51ms/step - loss: 0.0043
# Epoch 61/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0035
# Epoch 62/100
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0039
# Epoch 63/100
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0044
# Epoch 64/100
# 19/19 [==============================] - 1s 56ms/step - loss: 0.0045
# Epoch 65/100
# 19/19 [==============================] - 1s 55ms/step - loss: 0.0044
# Epoch 66/100
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0037
# Epoch 67/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0034
# Epoch 68/100
# 19/19 [==============================] - 1s 55ms/step - loss: 0.0033
# Epoch 69/100
# 19/19 [==============================] - 1s 54ms/step - loss: 0.0036
# Epoch 70/100
# 19/19 [==============================] - 1s 55ms/step - loss: 0.0041
# Epoch 71/100
# 19/19 [==============================] - 1s 55ms/step - loss: 0.0035
# Epoch 72/100
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0039
# Epoch 73/100
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0037
# Epoch 74/100
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0039
# Epoch 75/100
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0044
# Epoch 76/100
# 19/19 [==============================] - 1s 56ms/step - loss: 0.0043
# Epoch 77/100
# 19/19 [==============================] - 1s 55ms/step - loss: 0.0038
# Epoch 78/100
# 19/19 [==============================] - 1s 57ms/step - loss: 0.0053
# Epoch 79/100
# 19/19 [==============================] - 1s 56ms/step - loss: 0.0039
# Epoch 80/100
# 19/19 [==============================] - 1s 56ms/step - loss: 0.0041
# Epoch 81/100
# 19/19 [==============================] - 1s 55ms/step - loss: 0.0048
# Epoch 82/100
# 19/19 [==============================] - 1s 72ms/step - loss: 0.0047
# Epoch 83/100
# 19/19 [==============================] - 1s 69ms/step - loss: 0.0046
# Epoch 84/100
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0046
# Epoch 85/100
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0038
# Epoch 86/100
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0042
# Epoch 87/100
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0035
# Epoch 88/100
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0039
# Epoch 89/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0039
# Epoch 90/100
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0041
# Epoch 91/100
# 19/19 [==============================] - 1s 64ms/step - loss: 0.0031
# Epoch 92/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0036
# Epoch 93/100
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0036
# Epoch 94/100
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0036
# Epoch 95/100
# 19/19 [==============================] - 1s 57ms/step - loss: 0.0035
# Epoch 96/100
# 19/19 [==============================] - 1s 57ms/step - loss: 0.0035
# Epoch 97/100
# 19/19 [==============================] - 1s 57ms/step - loss: 0.0034
# Epoch 98/100
# 19/19 [==============================] - 1s 57ms/step - loss: 0.0033
# Epoch 99/100
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0033
# Epoch 100/100
# 19/19 [==============================] - 1s 58ms/step - loss: 0.0031

# %%
history_lstm = fit_model(model_lstm)
# Out:
# Epoch 1/100
# 19/19 [==============================] - 6s 83ms/step - loss: 0.0676
# Epoch 2/100
# 19/19 [==============================] - 2s 80ms/step - loss: 0.0208
# Epoch 3/100
# 19/19 [==============================] - 2s 92ms/step - loss: 0.0208
# Epoch 4/100
# 19/19 [==============================] - 2s 80ms/step - loss: 0.0199
# Epoch 5/100
# 19/19 [==============================] - 2s 83ms/step - loss: 0.0185
# Epoch 6/100
# 19/19 [==============================] - 2s 92ms/step - loss: 0.0175
# Epoch 7/100
# 19/19 [==============================] - 2s 84ms/step - loss: 0.0165
# Epoch 8/100
# 19/19 [==============================] - 2s 83ms/step - loss: 0.0152
# Epoch 9/100
# 19/19 [==============================] - 1s 78ms/step - loss: 0.0137
# Epoch 10/100
# 19/19 [==============================] - 2s 80ms/step - loss: 0.0122
# Epoch 11/100
# 19/19 [==============================] - 2s 81ms/step - loss: 0.0121
# Epoch 12/100
# 19/19 [==============================] - 2s 79ms/step - loss: 0.0114
# Epoch 13/100
# 19/19 [==============================] - 2s 85ms/step - loss: 0.0108
# Epoch 14/100
# 19/19 [==============================] - 2s 83ms/step - loss: 0.0107
# Epoch 15/100
# 19/19 [==============================] - 2s 80ms/step - loss: 0.0096
# Epoch 16/100
# 19/19 [==============================] - 2s 81ms/step - loss: 0.0095
# Epoch 17/100
# 19/19 [==============================] - 2s 82ms/step - loss: 0.0092
# Epoch 18/100
# 19/19 [==============================] - 2s 82ms/step - loss: 0.0092
# Epoch 19/100
# 19/19 [==============================] - 2s 85ms/step - loss: 0.0092
# Epoch 20/100
# 19/19 [==============================] - 1s 78ms/step - loss: 0.0078
# Epoch 21/100
# 19/19 [==============================] - 1s 79ms/step - loss: 0.0096
# Epoch 22/100
# 19/19 [==============================] - 1s 78ms/step - loss: 0.0084
# Epoch 23/100
# 19/19 [==============================] - 2s 80ms/step - loss: 0.0098
# Epoch 24/100
# 19/19 [==============================] - 2s 81ms/step - loss: 0.0085
# Epoch 25/100
# 19/19 [==============================] - 1s 78ms/step - loss: 0.0084
# Epoch 26/100
# 19/19 [==============================] - 1s 79ms/step - loss: 0.0103
# Epoch 27/100
# 19/19 [==============================] - 2s 79ms/step - loss: 0.0075
# Epoch 28/100
# 19/19 [==============================] - 2s 79ms/step - loss: 0.0078
# Epoch 29/100
# 19/19 [==============================] - 1s 78ms/step - loss: 0.0087
# Epoch 30/100
# 19/19 [==============================] - 1s 79ms/step - loss: 0.0076
# Epoch 31/100
# 19/19 [==============================] - 2s 83ms/step - loss: 0.0085
# Epoch 32/100
# 19/19 [==============================] - 1s 78ms/step - loss: 0.0074
# Epoch 33/100
# 19/19 [==============================] - 2s 79ms/step - loss: 0.0077
# Epoch 34/100
# 19/19 [==============================] - 2s 79ms/step - loss: 0.0079
# Epoch 35/100
# 19/19 [==============================] - 2s 79ms/step - loss: 0.0079
# Epoch 36/100
# 19/19 [==============================] - 2s 80ms/step - loss: 0.0075
# Epoch 37/100
# 19/19 [==============================] - 2s 79ms/step - loss: 0.0085
# Epoch 38/100
# 19/19 [==============================] - 2s 80ms/step - loss: 0.0070
# Epoch 39/100
# 19/19 [==============================] - 2s 80ms/step - loss: 0.0081
# Epoch 40/100
# 19/19 [==============================] - 1s 78ms/step - loss: 0.0070
# Epoch 41/100
# 19/19 [==============================] - 2s 79ms/step - loss: 0.0074
# Epoch 42/100
# 19/19 [==============================] - 2s 79ms/step - loss: 0.0070
# Epoch 43/100
# 19/19 [==============================] - 2s 80ms/step - loss: 0.0070
# Epoch 44/100
# 19/19 [==============================] - 2s 81ms/step - loss: 0.0071
# Epoch 45/100
# 19/19 [==============================] - 2s 80ms/step - loss: 0.0074
# Epoch 46/100
# 19/19 [==============================] - 2s 79ms/step - loss: 0.0068
# Epoch 47/100
# 19/19 [==============================] - 2s 82ms/step - loss: 0.0070
# Epoch 48/100
# 19/19 [==============================] - 1s 78ms/step - loss: 0.0069
# Epoch 49/100
# 19/19 [==============================] - 1s 78ms/step - loss: 0.0065
# Epoch 50/100
# 19/19 [==============================] - 2s 87ms/step - loss: 0.0068
# Epoch 51/100
# 19/19 [==============================] - 2s 79ms/step - loss: 0.0066
# Epoch 52/100
# 19/19 [==============================] - 2s 79ms/step - loss: 0.0062
# Epoch 53/100
# 19/19 [==============================] - 2s 79ms/step - loss: 0.0063
# Epoch 54/100
# 19/19 [==============================] - 2s 79ms/step - loss: 0.0065
# Epoch 55/100
# 19/19 [==============================] - 2s 80ms/step - loss: 0.0070
# Epoch 56/100
# 19/19 [==============================] - 2s 89ms/step - loss: 0.0057
# Epoch 57/100
# 19/19 [==============================] - 2s 80ms/step - loss: 0.0068
# Epoch 58/100
# 19/19 [==============================] - 2s 82ms/step - loss: 0.0057
# Epoch 59/100
# 19/19 [==============================] - 1s 79ms/step - loss: 0.0061
# Epoch 60/100
# 19/19 [==============================] - 1s 78ms/step - loss: 0.0055
# Epoch 61/100
# 19/19 [==============================] - 1s 78ms/step - loss: 0.0063
# Epoch 62/100
# 19/19 [==============================] - 2s 79ms/step - loss: 0.0059
# Epoch 63/100
# 19/19 [==============================] - 1s 78ms/step - loss: 0.0068
# Epoch 64/100
# 19/19 [==============================] - 2s 79ms/step - loss: 0.0057
# Epoch 65/100
# 19/19 [==============================] - 2s 81ms/step - loss: 0.0053
# Epoch 66/100
# 19/19 [==============================] - 2s 79ms/step - loss: 0.0053
# Epoch 67/100
# 19/19 [==============================] - 1s 78ms/step - loss: 0.0053
# Epoch 68/100
# 19/19 [==============================] - 1s 78ms/step - loss: 0.0056
# Epoch 69/100
# 19/19 [==============================] - 2s 79ms/step - loss: 0.0052
# Epoch 70/100
# 19/19 [==============================] - 2s 79ms/step - loss: 0.0048
# Epoch 71/100
# 19/19 [==============================] - 2s 80ms/step - loss: 0.0053
# Epoch 72/100
# 19/19 [==============================] - 1s 78ms/step - loss: 0.0058
# Epoch 73/100
# 19/19 [==============================] - 1s 78ms/step - loss: 0.0050
# Epoch 74/100
# 19/19 [==============================] - 2s 79ms/step - loss: 0.0058
# Epoch 75/100
# 19/19 [==============================] - 1s 78ms/step - loss: 0.0053
# Epoch 76/100
# 19/19 [==============================] - 2s 79ms/step - loss: 0.0043
# Epoch 77/100
# 19/19 [==============================] - 2s 80ms/step - loss: 0.0050
# Epoch 78/100
# 19/19 [==============================] - 2s 80ms/step - loss: 0.0047
# Epoch 79/100
# 19/19 [==============================] - 1s 78ms/step - loss: 0.0054
# Epoch 80/100
# 19/19 [==============================] - 1s 78ms/step - loss: 0.0049
# Epoch 81/100
# 19/19 [==============================] - 2s 79ms/step - loss: 0.0043
# Epoch 82/100
# 19/19 [==============================] - 2s 80ms/step - loss: 0.0040
# Epoch 83/100
# 19/19 [==============================] - 2s 80ms/step - loss: 0.0043
# Epoch 84/100
# 19/19 [==============================] - 2s 81ms/step - loss: 0.0044
# Epoch 85/100
# 19/19 [==============================] - 1s 78ms/step - loss: 0.0051
# Epoch 86/100
# 19/19 [==============================] - 2s 80ms/step - loss: 0.0045
# Epoch 87/100
# 19/19 [==============================] - 1s 78ms/step - loss: 0.0049
# Epoch 88/100
# 19/19 [==============================] - 1s 78ms/step - loss: 0.0041
# Epoch 89/100
# 19/19 [==============================] - 2s 82ms/step - loss: 0.0051
# Epoch 90/100
# 19/19 [==============================] - 2s 79ms/step - loss: 0.0041
# Epoch 91/100
# 19/19 [==============================] - 2s 79ms/step - loss: 0.0049
# Epoch 92/100
# 19/19 [==============================] - 2s 79ms/step - loss: 0.0043
# Epoch 93/100
# 19/19 [==============================] - 1s 78ms/step - loss: 0.0042
# Epoch 94/100
# 19/19 [==============================] - 2s 80ms/step - loss: 0.0046
# Epoch 95/100
# 19/19 [==============================] - 2s 82ms/step - loss: 0.0041
# Epoch 96/100
# 19/19 [==============================] - 1s 78ms/step - loss: 0.0046
# Epoch 97/100
# 19/19 [==============================] - 1s 79ms/step - loss: 0.0043
# Epoch 98/100
# 19/19 [==============================] - 2s 79ms/step - loss: 0.0038
# Epoch 99/100
# 19/19 [==============================] - 1s 78ms/step - loss: 0.0039
# Epoch 100/100
# 19/19 [==============================] - 1s 79ms/step - loss: 0.0042

# %%
# model_gru.save("model_gru.keras")
# model_lstm.save("model_lstm.keras")

# %%
batch_size = [16, 32, 64]
epochs = [20, 50, 10]
optimizers = ['adam', 'rmsprop']
param_grid = dict(batch_size=batch_size, epochs=epochs, optimizer=optimizers)
param_grid
# Out:
# {'batch_size': [16, 32, 64],
#  'epochs': [20, 50, 10],
#  'optimizer': ['adam', 'rmsprop']}

# %%
# from sklearn.model_selection import GridSearchCV
# from scikeras.wrappers import KerasClassifier

# model = KerasClassifier(build_fn=model_lstm, verbose=1)

# grid = GridSearchCV(estimator=model, param_grid=param_grid, cv=5)

# grid_result = grid.fit(X_train, y_train)

# %%
# # summarize results
# print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# means = grid_result.cv_results_['mean_test_score']
# stds = grid_result.cv_results_['std_test_score']
# params = grid_result.cv_results_['params']
# for mean, stdev, param in zip(means, stds, params):
#     print("%f (%f) with: %r" % (mean, stdev, param))

# %% [markdown]
# ### Đánh giá kết quả

# %%
# Plot train loss and validation loss
def plot_loss (history, model_name):
    plt.figure(figsize = (10, 6))
    plt.plot(history.history['loss'])
    plt.title('Model Train vs Validation Loss for ' + model_name)
    plt.ylabel('Loss')
    plt.xlabel('epoch')
    plt.legend(['Train loss', 'Validation loss'], loc='upper right')

plot_loss (history_gru, 'GRU')
plot_loss (history_lstm, 'LSTM')

# %%
# Transform data back to original data space
y_test = scaler.inverse_transform(y_test)
y_train = scaler.inverse_transform(y_train)

# Make prediction
def prediction(model):
    prediction = model.predict(X_test)
    prediction = scaler.inverse_transform(prediction)
    return prediction

def prediction_train(model):
    prediction = model.predict(X_train)
    prediction = scaler.inverse_transform(prediction)
    return prediction


prediction_gru = prediction(model_gru)
prediction_gru_train = prediction_train(model_gru)

prediction_lstm = prediction(model_lstm)
prediction_lstm_train = prediction_train(model_lstm)
# Out:
# 4/4 [==============================] - 1s 15ms/step
# 19/19 [==============================] - 0s 17ms/step
# 4/4 [==============================] - 1s 27ms/step
# 19/19 [==============================] - 1s 26ms/step

# %%
# Plot test data vs prediction
def plot_future(prediction, model_name, y_test):
    
    plt.figure(figsize=(10, 6))
    
    range_future = len(prediction)

    plt.plot(np.arange(range_future), np.array(y_test), label='Test data')
    plt.plot(np.arange(range_future), np.array(prediction),label='Prediction')

    plt.title('Test data vs prediction for ' + model_name)
    plt.legend(loc='upper left')
    plt.xlabel('Time (day)')
    plt.ylabel('Daily water consumption ($m^3$/capita.day)')
       
plot_future(prediction_gru, 'GRU', y_test)
plot_future(prediction_gru_train, 'GRU', y_train)


plot_future(prediction_lstm, 'LSTM', y_test)
plot_future(prediction_lstm_train, 'LSTM', y_train)



from sklearn.metrics import r2_score 
# Calculate MAE and RMSE
def evaluate_prediction(predictions, actual, model_name, data = 'TEST'):
    errors = predictions - actual
    mse = np.square(errors).mean()
    rmse = np.sqrt(mse)
    mae = np.abs(errors).mean()

    print(data)
    print(model_name + ':')
    print('Mean Absolute Error: {:.4f}'.format(mae))
    print('Root Mean Square Error: {:.4f}'.format(rmse))
    print('MAE: {:.4f}'.format(mae))
    print('R2 Score: {:.4f}'.format(r2_score(predictions, actual)))
    print('')

evaluate_prediction(prediction_gru_train, y_train, 'GRU', 'TRAIN')
evaluate_prediction(prediction_lstm_train, y_train, 'LSTM', 'TRAIN')

evaluate_prediction(prediction_gru, y_test, 'GRU')
evaluate_prediction(prediction_lstm, y_test, 'LSTM')
# Out:
# TRAIN
# GRU:
# Mean Absolute Error: 172.1905
# Root Mean Square Error: 302.7885
# MAE: 172.1905
# R2 Score: 0.9270
#
# TRAIN
# LSTM:
# Mean Absolute Error: 153.3664
# Root Mean Square Error: 298.9603
# MAE: 153.3664
# R2 Score: 0.9282
#
# TEST
# GRU:
# Mean Absolute Error: 103.7961
# Root Mean Square Error: 198.2599
# MAE: 103.7961
# R2 Score: 0.9261
#
# TEST
# LSTM:
# Mean Absolute Error: 173.1555
# Root Mean Square Error: 241.8457
# MAE: 173.1555
# R2 Score: 0.8960

# %%
def predict(forecast_num, model,data,look_back):
  prediction_list = data[-look_back:]

  for _ in range(forecast_num):
      x = prediction_list[-look_back:]
      x = x.reshape((1, look_back, 1))
      out = model.predict(x)[0][0]
      prediction_list = np.append(prediction_list, out)
  prediction_list = prediction_list[look_back-1:]

  return prediction_list

def predict_dates(forecast_num, data):
    last_date = data.index[-1]
    prediction_dates = pd.date_range(last_date, periods=forecast_num+1).tolist()
    return prediction_dates

# %%
forecast_num = 12 #number of day to predict after the last date in data
forecast=predict(forecast_num, model=model_lstm,data=X_test[-1:],look_back=48)
forecast_date=predict_dates(forecast_num, df)
# Out:
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step

# %%
plt.figure(figsize=(10, 6))
    
f =  scaler.inverse_transform(forecast.reshape(-1, 1))
plt.plot(np.array(f),label='Prediction')

plt.title('Test data vs prediction for ')
plt.legend(loc='upper left')
plt.xlabel('Time (day)')
plt.ylabel('Daily water consumption ($m^3$/capita.day)')
# Out:
# Text(0, 0.5, 'Daily water consumption ($m^3$/capita.day)')

# %%
forecast_num = 12 #number of day to predict after the last date in data
forecast=predict(forecast_num, model=model_gru,data=X_test[-1:],look_back=48)
forecast_date=predict_dates(forecast_num, df)
# Out:
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step

# %%
plt.figure(figsize=(10, 6))
    
f =  scaler.inverse_transform(forecast.reshape(-1, 1))
plt.plot(np.array(f),label='Prediction')

plt.title('Test data vs prediction for ')
plt.legend(loc='upper left')
plt.xlabel('Time (day)')
plt.ylabel('Daily water consumption ($m^3$/capita.day)')
# Out:
# Text(0, 0.5, 'Daily water consumption ($m^3$/capita.day)')
